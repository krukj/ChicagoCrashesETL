# %%
import pandas as pd

# %%
dim_crash_info = pd.read_pickle("dim_crash_info.pkl")
fact_crash = pd.read_pickle("fact_crash.pkl")
dim_vehicle = pd.read_pickle("dim_vehicle.pkl")
fact_weather = pd.read_pickle("fact_weather.pkl")

# %%
dim_crash_info.head(3)
# Out:
#                                      CRASH_RECORD_ID TRAFFIC_CONTROL_DEVICE  \
# 0  032ca7e09951de4385eec78a50a5f9f33b217838578b29...            NO CONTROLS
# 1  71065ad347ee197080534e112b27c8a5b6fb8d9bbde2c3...            NO CONTROLS
# 2  9c2724305c03bf461d72cbcf2879c96b86ed5e180b62be...         TRAFFIC SIGNAL
#
#        DEVICE_CONDITION      FIRST_CRASH_TYPE             TRAFFICWAY_TYPE  \
# 0           NO CONTROLS  PARKED MOTOR VEHICLE                 NOT DIVIDED
# 1           NO CONTROLS          FIXED OBJECT  DIVIDED - W/MEDIAN BARRIER
# 2  FUNCTIONING PROPERLY          FIXED OBJECT  DIVIDED - W/MEDIAN BARRIER
#
#             ALIGNMENT ROADWAY_SURFACE_COND ROAD_DEFECT REPORT_TYPE  \
# 0   STRAIGHT ON GRADE        SNOW OR SLUSH  NO DEFECTS    ON SCENE
# 1  STRAIGHT AND LEVEL                  DRY  NO DEFECTS    ON SCENE
# 2  STRAIGHT AND LEVEL                  DRY     UNKNOWN    ON SCENE
#
#                          CRASH_TYPE       DAMAGE      PRIM_CONTRIBUTORY_CAUSE  \
# ...

# %%
fact_crash.head(3)
# Out:
#                                      CRASH_RECORD_ID  NUM_UNITS  \
# 0  032ca7e09951de4385eec78a50a5f9f33b217838578b29...          3
# 1  71065ad347ee197080534e112b27c8a5b6fb8d9bbde2c3...          1
# 2  9c2724305c03bf461d72cbcf2879c96b86ed5e180b62be...          1
#
#    INJURIES_TOTAL  INJURIES_FATAL  INJURIES_INCAPACITATING  \
# 0               0               0                        0
# 1               2               0                        0
# 2              -1              -1                       -1
#
#    INJURIES_NON_INCAPACITATING  INJURIES_REPORTED_NOT_EVIDENT  \
# 0                            0                              0
# 1                            2                              0
# 2                           -1                             -1
#
#    INJURIES_NO_INDICATION  INJURIES_UNKNOWN        FACT_CRASH_KEY
# 0                       1                 0    102052558975241319
# 1                       1                 0   2989301628946909366
# ...

# %%
dim_vehicle.head(3)
# Out:
#    CRASH_UNIT_ID                                    CRASH_RECORD_ID UNIT_TYPE  \
# 0         813884  032ca7e09951de4385eec78a50a5f9f33b217838578b29...    PARKED
# 1         813885  032ca7e09951de4385eec78a50a5f9f33b217838578b29...    PARKED
# 2         813890  032ca7e09951de4385eec78a50a5f9f33b217838578b29...    DRIVER
#
#    NUM_PASSENGERS  VEHICLE_ID       MAKE    MODEL  VEHICLE_YEAR  \
# 0              -1    772693.0  CHEVROLET    CRUZE          2016
# 1              -1    772695.0       JEEP  Liberty          2004
# 2              -1    772699.0    UNKNOWN  UNKNOWN            -1
#
#   VEHICLE_DEFECT VEHICLE_TYPE VEHICLE_USE TRAVEL_DIRECTION        MANEUVER  \
# 0           NONE    PASSENGER  NOT IN USE                S          PARKED
# 1           NONE    PASSENGER  NOT IN USE                S  STRAIGHT AHEAD
# 2        UNKNOWN   UNKNOWN/NA  UNKNOWN/NA                S      UNKNOWN/NA
#
#    OCCUPANT_CNT FIRST_CONTACT_POINT           VEHICLE_KEY  CRASH_INFO_KEY
# ...

# %%
fact_weather.head(3)
# Out:
#               datetime  temp  feelslike  dew   humidity  precip  precipprob  \
# 0  2018-12-01T00:00:00   2.7       -2.3  0.2  84.010002     0.0           0
# 1  2018-12-01T01:00:00   2.0       -3.0  0.1  87.480003     0.0           0
# 2  2018-12-01T02:00:00   2.0       -2.2  0.1  87.480003     0.0           0
#
#   preciptype  snow  snowdepth  windgust  windspeed winddir  sealevelpressure  \
# 0       NONE   0.0        0.0       0.0  23.100000      NE       1016.400024
# 1       NONE   0.0        0.0       0.0  22.200001       E       1016.000000
# 2       NONE   0.0        0.0       0.0  16.500000      NE       1015.200012
#
#    cloudcover  visibility  solarradiation  solarenergy  uvindex conditions
# 0       100.0         7.3             0.0          0.0        0   Overcast
# 1       100.0         5.0             0.0          0.0        0   Overcast
# 2       100.0         4.3             0.0          0.0        0   Overcast

# %%
dim_crash_info
# Out:
# 0            87770406243964446
# 1         13076194814157957103
# 2          7935312456322554172
# 3         12518242837129930569
# 4         14348931642873109510
#                   ...
# 117759    11416572419770690828
# 117760    13920594057794690858
# 117761     5815243703792704096
# 117762     4209193262676221213
# 117763     6663495284153142405
# Name: CRASH_INFO_KEY, Length: 117764, dtype: uint64
